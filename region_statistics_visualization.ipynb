# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cd '/Volumes/My Book/rabies_tracing_images/pv_cre_starter_cells/XH_12_07_17/vglut_presynaptic_647/01_counts'
# Out:
# /Volumes/My Book/rabies_tracing_images/pv_cre_starter_cells/XH_12_07_17/vglut_presynaptic_647/01_counts

# %%
summary_df = pd.read_csv('./summary.csv')

# %%
bool_mask = (summary_df['presynaptic']>10)
plt.scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic/starter'])
plt.title('Presynaptic cells/Starter vs. # of Starter cells in Region')
plt.ylabel('Presynaptic cells/Starter')
plt.xlabel('# of Starter cells in region')
# Out:
# Text(0.5,0,'# of Starter cells in region')

# %%
bool_mask = (summary_df['presynaptic']>-1)
plt.scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic vglut/presynaptic'])
plt.title("Presynaptic Vglut/presynaptic vs. # of Starter cells in Region")
plt.ylabel('Presynaptic Vglut/presynaptic')
plt.xlabel('# of Starter cells in region')
# Out:
# Text(0.5,0,'# of Starter cells in region')
