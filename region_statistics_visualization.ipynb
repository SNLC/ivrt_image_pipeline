# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cd '/Volumes/My Book/rabies_tracing_images/vip_cre_starter_cells/ML_08_15_17/pv_presynaptic_647'
# Out:
# /Volumes/My Book/rabies_tracing_images/vip_cre_starter_cells/ML_08_15_17/pv_presynaptic_647

# %%
summary_df = pd.read_csv('/summary.csv')

# %%
bool_mask = (summary_df['presynaptic']>10)
plt.scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic/starter'])
plt.title('Presynaptic cells/Starter vs. # of Starter cells in Region')
plt.ylabel('Presynaptic cells/Starter')
plt.xlabel('# of Starter cells in region')
# Out:
# Text(0.5,0,'# of Starter cells in region')

# %%
bool_mask = (summary_df['presynaptic']>-1)
plt.scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic pv/pv'])
plt.title("Presynaptic pv/total pv vs. # of Starter cells in Region")
plt.ylabel('Presynaptic pv/total pv')
plt.xlabel('# of Starter cells in region')
# Out:
# Text(0.5,0,'# of Starter cells in region')
