# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os

# %%
cd /Volumes/My Book/rabies_tracing_images/vip_cre_starter_cells
# Out:
# /Volumes/My Book/rabies_tracing_images/vip_cre_starter_cells

# %%
csv_list = glob.glob("**/summarized_counts/summary.csv", recursive=True)
df_list = [pd.read_csv(f) for f in csv_list]

# %%
summary_df = pd.concat(df_list)

# %%
summary_df
# Out:
#    Coverslip ID Experiment ID  Region ID      Starter Cell Type  \
# 0     38_counts   ML_08_15_17        1.0  vip_cre_starter_cells
# 1     38_counts   ML_08_15_17        2.0  vip_cre_starter_cells
# 2     38_counts   ML_08_15_17        3.0  vip_cre_starter_cells
# 3     38_counts   ML_08_15_17        4.0  vip_cre_starter_cells
# 4     38_counts   ML_08_15_17        5.0  vip_cre_starter_cells
# 5     38_counts   ML_08_15_17        6.0  vip_cre_starter_cells
# 6     39_counts   ML_08_15_17        1.0  vip_cre_starter_cells
# 7     40_counts   ML_08_15_17        1.0  vip_cre_starter_cells
# 8     40_counts   ML_08_15_17        2.0  vip_cre_starter_cells
# 9     40_counts   ML_08_15_17        3.0  vip_cre_starter_cells
# 10    40_counts   ML_08_15_17        4.0  vip_cre_starter_cells
# 11    40_counts   ML_08_15_17        5.0  vip_cre_starter_cells
# 12    40_counts   ML_08_15_17        6.0  vip_cre_starter_cells
# 13    40_counts   ML_08_15_17        7.0  vip_cre_starter_cells
# ...

# %%
bool_mask = (summary_df['Target Cell Type'] == 'vip')

fig, ax = plt.subplots(1,3)
fig.set_size_inches(15, 4)
fig.suptitle("Summarized vip to vip connectivity", fontsize=20, y=1.08)

ax[0].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic/starter'])
ax[0].set_title('Presynaptic cells/Starter vs. \n # of Starter cells in Region')
ax[0].set_ylabel('Presynaptic cells/Starter')
ax[0].set_xlabel('# of Starter cells in region')

ax[1].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic vip/vip'])
ax[1].set_title('Presynaptic vip/vip vs. \n # of Starter cells in Region')
ax[1].set_ylabel('Presynaptic vip/vip')
ax[1].set_xlabel('# of Starter cells in region')

ax[2].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic vip/presynaptic'])
ax[2].set_title('Presynaptic vip/presynaptic vs. \n # of Starter cells in Region')
ax[2].set_ylabel('Presynaptic vip/presynaptic')
ax[2].set_xlabel('# of Starter cells in region')

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/python3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# ~/.local/share/virtualenvs/python3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [presynaptic vip/vip] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-cba381ea961a> in <module>()
# ...

# %%
bool_mask = (summary_df['Target Cell Type'] == 'sst')

fig, ax = plt.subplots(1,3)
fig.set_size_inches(15, 4)
fig.suptitle("Summarized sst to vip connectivity", fontsize=20, y=1.08)

ax[0].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic/starter'])
ax[0].set_title('Presynaptic cells/Starter vs. \n # of Starter cells in Region')
ax[0].set_ylabel('Presynaptic cells/Starter')
ax[0].set_xlabel('# of Starter cells in region')

ax[1].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic sst/sst'])
ax[1].set_title('Presynaptic sst/sst vs. \n # of Starter cells in Region')
ax[1].set_ylabel('Presynaptic sst/sst')
ax[1].set_xlabel('# of Starter cells in region')

ax[2].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic sst/presynaptic'])
ax[2].set_title('Presynaptic sst/presynaptic vs. \n # of Starter cells in Region')
ax[2].set_ylabel('Presynaptic sst/presynaptic')
ax[2].set_xlabel('# of Starter cells in region')

plt.tight_layout()

# %%
bool_mask = (summary_df['Target Cell Type'] == 'pv')

fig, ax = plt.subplots(1,3)
fig.set_size_inches(15, 4)
fig.suptitle("Summarized pv to vip connectivity", fontsize=20, y=1.08)

ax[0].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic/starter'])
ax[0].set_title('Presynaptic cells/Starter vs. \n # of Starter cells in Region')
ax[0].set_ylabel('Presynaptic cells/Starter')
ax[0].set_xlabel('# of Starter cells in region')

ax[1].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic pv/pv'])
ax[1].set_title('Presynaptic pv/pv vs. \n # of Starter cells in Region')
ax[1].set_ylabel('Presynaptic pv/pv')
ax[1].set_xlabel('# of Starter cells in region')

ax[2].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic pv/presynaptic'])
ax[2].set_title('Presynaptic pv/presynaptic vs. \n # of Starter cells in Region')
ax[2].set_ylabel('Presynaptic pv/presynaptic')
ax[2].set_xlabel('# of Starter cells in region')

plt.tight_layout()

# %%
bool_mask = (summary_df['Target Cell Type'] == 'vglut')

fig, ax = plt.subplots(1,3)
fig.set_size_inches(15, 4)
fig.suptitle("Summarized vglut to vip connectivity", fontsize=20, y=1.08)

ax[0].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic/starter'])
ax[0].set_title('Presynaptic cells/Starter vs. \n # of Starter cells in Region')
ax[0].set_ylabel('Presynaptic cells/Starter')
ax[0].set_xlabel('# of Starter cells in region')

ax[1].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic vglut/vglut'])
ax[1].set_title('Presynaptic vglut/vglut vs. \n # of Starter cells in Region')
ax[1].set_ylabel('Presynaptic vglut/vglut')
ax[1].set_xlabel('# of Starter cells in region')

ax[2].scatter(summary_df.loc[bool_mask, 'starter'], summary_df.loc[bool_mask, 'presynaptic vglut/presynaptic'])
ax[2].set_title('Presynaptic vglut/presynaptic vs. \n # of Starter cells in Region')
ax[2].set_ylabel('Presynaptic vglut/presynaptic')
ax[2].set_xlabel('# of Starter cells in region')

plt.tight_layout()
